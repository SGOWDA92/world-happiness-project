# %% [markdown]
# # WORLD HAPPINESS  REPORT

# %% [markdown]
# Submitted by:
# sucharitha A M
# 1829 batch

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Examining the Data

# %%
df=pd.read_csv("world happiness.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# we have 158 rows and 12 columns in dataset

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# we have float type value in all independent variables
# and country and region is our target variables and happiness
# rank is our intial variable in we have class

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Here all values will be zero

# %%
df['Country'].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
#        'Algeria', 'Kosovo', 'Turkmenistan', 'Mauritius', 'Hong Kong',
#        'Estonia', 'Indonesia', 'Vietnam', 'Turkey', 'Kyrgyzstan',
#        'Nigeria', 'Bhutan', 'Azerbaijan', 'Pakistan', 'Jordan',
#        'Montenegro', 'China', 'Zambia', 'Romania', 'Serbia', 'Portugal',
#        'Latvia', 'Philippines', 'Somaliland region', 'Morocco',
#        'Macedonia', 'Mozambique', 'Albania', 'Bosnia and Herzegovina',
#        'Lesotho', 'Dominican Republic', 'Laos', 'Mongolia', 'Swaziland',
#        'Greece', 'Lebanon', 'Hungary', 'Honduras', 'Tajikistan',
#        'Tunisia', 'Palestinian Territories', 'Bangladesh', 'Iran',
#        'Ukraine', 'Iraq', 'South Africa', 'Ghana', 'Zimbabwe', 'Liberia',
#        'India', 'Sudan', 'Haiti', 'Congo (Kinshasa)', 'Nepal', 'Ethiopia',
#        'Sierra Leone', 'Mauritania', 'Kenya', 'Djibouti', 'Armenia',
#        'Botswana', 'Myanmar', 'Georgia', 'Malawi', 'Sri Lanka',
#        'Cameroon', 'Bulgaria', 'Egypt', 'Yemen', 'Angola', 'Mali',
#        'Congo (Brazzaville)', 'Comoros', 'Uganda', 'Senegal', 'Gabon',
#        'Niger', 'Cambodia', 'Tanzania', 'Madagascar',
#        'Central African Republic', 'Chad', 'Guinea', 'Ivory Coast',
#        'Burkina Faso', 'Afghanistan', 'Rwanda', 'Benin', 'Syria',
#        'Burundi', 'Togo'], dtype=object)

# %% [markdown]
# There are so many unique country in df['Country']

# %%
df['Country'].value_counts()
# Out:
# Israel                     1
# Czech Republic             1
# Denmark                    1
# Sri Lanka                  1
# Jordan                     1
#                           ..
# Croatia                    1
# Palestinian Territories    1
# Paraguay                   1
# South Korea                1
# Bosnia and Herzegovina     1
# Name: Country, Length: 158, dtype: int64

# %% [markdown]
# here country lenghth is 158 and dtype is int64

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %% [markdown]
# here so many refion in df['Region']

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# here region is dtype64

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate analysis

# %%
sn.countplot(df['Country']);

# %% [markdown]
# All columns are equaly distributed there is no imbalance issue exits

# %%
sn.countplot(df['Region']);

# %% [markdown]
# All classes are not equally distributed there is  class imbalance issue exits

# %%
sn.displot(df['Happiness Rank'])

# %% [markdown]
# Here some coulmns are eqully distrubuted and some columns are not equally distrubuted beacause imbalance issue

# %%
sn.displot(df['Happiness Score'])

# %% [markdown]
# All classes are not equally distrbuted because imbalance issue

# %%
sn.boxplot(df["Happiness Rank"])
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
sn.boxplot(df["Happiness Score"])
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [markdown]
# There as no outlet in these happiness rank and happiness score columns

# %%
sn.boxplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error'>

# %%
sn.boxplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family'>

# %% [markdown]
# There is outlet on the standard error and family columns

# %% [markdown]
# # Bi Variate analysis

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Happiness Rank and Happiness Score')
sn.scatterplot(df['Happiness Rank'],df['Happiness Score']);

# %% [markdown]
# Here we can plot happiness rank and happiness score graph but not identified clearly

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Happiness Rank and Happiness Score')
sn.scatterplot(df['Happiness Rank'],df['Happiness Score'],hue=df["Country"]);

# %% [markdown]
# Here one more is added to happiness rank and happiness score that is country so here we can easily identified plots

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Happiness Rank and Happiness Score')
sn.scatterplot(df['Happiness Rank'],df['Happiness Score'],hue=df["Region"]);

# %% [markdown]
# Here one more is added to happiness rank and happiness score that is region we can easily identified here plots

# %%
sn.pairplot(df,hue="Country")

# %% [markdown]
# Here we can easily identified plots

# %%
sn.pairplot(df,hue="Region")

# %% [markdown]
# Here also we can easily identified plots

# %%
cor=df.corr()

# %%
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# Standard Error                       1.000000                 -0.217651
# Economy (GDP per Capita)            -0.217651                  1.000000
# Family                              -0.120728                  0.645299
# Health (Life Expectancy)            -0.310287                  0.816478
# Freedom                             -0.129773                  0.370300
# Trust (Government Corruption)       -0.178325                  0.307885
# Generosity                          -0.088439                 -0.010465
# Dystopia Residual                    0.083981                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Rank                -0.733644                 -0.735613 -0.556886
# Happiness Score                0.740605                  0.724200  0.568211
# Standard Error                -0.120728                 -0.310287 -0.129773
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
# Dystopia Residual              0.148117                  0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %% [markdown]
# Here reducing country and region

# %%
sn.heatmap(cor,annot=True,linewidth=1,linecolor='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# here comparing the columns rows

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Country"]=LE.fit_transform(df["Country"])

# %%
df["Country"].unique()
# Out:
# array([135,  58,  37, 105,  24,  45,  99, 134, 100,   6,  64,  33,   7,
#         91, 150,  18,  82,  63,  12, 148, 149, 106, 153, 123, 109,  49,
#         27, 115,  46,   4,  36, 151,  29, 140, 119, 129,  88, 137,  73,
#        132, 142,  42,  52, 152, 124,  68, 128,  40,   9,  65,  15,  92,
#        110,  70, 125,  81, 101, 111,  11, 113,  86,  34,  80, 117,  67,
#        104,  35,   2,  72, 145,  90,  56,  43,  60, 154, 144,  74, 103,
#         14,   8, 107,  69,  94,  28, 156, 116, 121, 114,  76, 112, 126,
#         95,  83,  96,   1,  16,  78,  39,  75,  93, 133,  51,  77,  57,
#         55, 138, 143, 108,  10,  61, 147,  62, 127,  50, 157,  79,  59,
#        131,  54,  32,  98,  44, 122,  89,  71,  38,   5,  17,  97,  48,
#         85, 130,  23,  19,  41, 155,   3,  87,  31,  30, 146, 120,  47,
#        102,  22, 139,  84,  25,  26,  53,  66,  20,   0, 118,  13, 136,
#         21, 141])

# %% [markdown]
# Here so many countries

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Region"]=LE.fit_transform(df["Region"])

# %%
df["Region"].unique()
# Out:
# array([9, 5, 0, 4, 3, 6, 1, 2, 8, 7])

# %% [markdown]
# Here only some regions is there

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %% [markdown]
# here the country and region will be added

# %%
sn.heatmap(cor,annot=True,linewidth=2,linecolor='pink')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Missing value treatment

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# here all sum values zero

# %%
df["Happiness Rank"]=df["Happiness Rank"].fillna(df["Happiness Rank"].mean())
df["Happiness Score"]=df["Happiness Score"].fillna(df["Happiness Score"].median())

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Here we can take happiness rank and happiness score mean and median

# %% [markdown]
# # Outlier removal

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))

new_df=df [(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (149, 12)

# %% [markdown]
# Here new difference shape 149 rows and 12 columns

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# Here 158 rows and 12 columns

# %%
(1/151)*100
# Out:
# 0.6622516556291391

# %% [markdown]
# Here new difference shape we can take and cross that term in 100 then we get value is below one

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Here skewness values will be changes

# %%
x=new_df.drop("Country",axis=1)
y=new_df["Country"]

# %%
x=new_df.drop("Region",axis=1)
y=new_df["Region"]

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# %%
for i in range(200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=i)
    from sklearn.tree import DecisionTreeClassifier
    lm=DecisionTreeClassifier()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=accuracy_score(y_test,pred)
    print(accu*100,"at random_state", i)
# Out:
# 54.0 at random_state 0
# 56.00000000000001 at random_state 1
# 54.0 at random_state 2
# 57.99999999999999 at random_state 3
# 60.0 at random_state 4
# 48.0 at random_state 5
# 42.0 at random_state 6
# 50.0 at random_state 7
# 46.0 at random_state 8
# 52.0 at random_state 9
# 54.0 at random_state 10
# 60.0 at random_state 11
# 52.0 at random_state 12
# 62.0 at random_state 13
# 68.0 at random_state 14
# 62.0 at random_state 15
# 56.00000000000001 at random_state 16
# 54.0 at random_state 17
# 54.0 at random_state 18
# 60.0 at random_state 19
# 57.99999999999999 at random_state 20
# 54.0 at random_state 21
# 46.0 at random_state 22
# 56.00000000000001 at random_state 23
# 57.99999999999999 at random_state 24
# 57.99999999999999 at random_state 25
# 57.99999999999999 at random_state 26
# 50.0 at random_state 27
# 52.0 at random_state 28
# 54.0 at random_state 29
# 52.0 at random_state 30
# 46.0 at random_state 31
# 56.00000000000001 at random_state 32
# 66.0 at random_state 33
# 54.0 at random_state 34
# 62.0 at random_state 35
# 57.99999999999999 at random_state 36
# 64.0 at random_state 37
# 64.0 at random_state 38
# 64.0 at random_state 39
# 60.0 at random_state 40
# 56.00000000000001 at random_state 41
# 56.00000000000001 at random_state 42
# 52.0 at random_state 43
# 42.0 at random_state 44
# 57.99999999999999 at random_state 45
# 48.0 at random_state 46
# 66.0 at random_state 47
# 60.0 at random_state 48
# 62.0 at random_state 49
# 54.0 at random_state 50
# 36.0 at random_state 51
# 48.0 at random_state 52
# 56.00000000000001 at random_state 53
# 64.0 at random_state 54
# 60.0 at random_state 55
# 54.0 at random_state 56
# 46.0 at random_state 57
# 66.0 at random_state 58
# 57.99999999999999 at random_state 59
# 54.0 at random_state 60
# 57.99999999999999 at random_state 61
# 54.0 at random_state 62
# 57.99999999999999 at random_state 63
# 48.0 at random_state 64
# 54.0 at random_state 65
# 52.0 at random_state 66
# 54.0 at random_state 67
# 72.0 at random_state 68
# 57.99999999999999 at random_state 69
# 42.0 at random_state 70
# 57.99999999999999 at random_state 71
# 66.0 at random_state 72
# 56.00000000000001 at random_state 73
# 66.0 at random_state 74
# 48.0 at random_state 75
# 50.0 at random_state 76
# 57.99999999999999 at random_state 77
# 40.0 at random_state 78
# 50.0 at random_state 79
# 40.0 at random_state 80
# 66.0 at random_state 81
# 57.99999999999999 at random_state 82
# 57.99999999999999 at random_state 83
# 66.0 at random_state 84
# 56.00000000000001 at random_state 85
# 64.0 at random_state 86
# 60.0 at random_state 87
# 62.0 at random_state 88
# 57.99999999999999 at random_state 89
# 54.0 at random_state 90
# 52.0 at random_state 91
# 68.0 at random_state 92
# 62.0 at random_state 93
# 60.0 at random_state 94
# 68.0 at random_state 95
# 66.0 at random_state 96
# 60.0 at random_state 97
# 48.0 at random_state 98
# 36.0 at random_state 99
# 68.0 at random_state 100
# 56.00000000000001 at random_state 101
# 57.99999999999999 at random_state 102
# 42.0 at random_state 103
# 50.0 at random_state 104
# 62.0 at random_state 105
# 52.0 at random_state 106
# 56.00000000000001 at random_state 107
# 38.0 at random_state 108
# 56.00000000000001 at random_state 109
# 44.0 at random_state 110
# 60.0 at random_state 111
# 54.0 at random_state 112
# 56.00000000000001 at random_state 113
# 48.0 at random_state 114
# 66.0 at random_state 115
# 44.0 at random_state 116
# 57.99999999999999 at random_state 117
# 64.0 at random_state 118
# 42.0 at random_state 119
# 62.0 at random_state 120
# 68.0 at random_state 121
# 56.00000000000001 at random_state 122
# 57.99999999999999 at random_state 123
# 54.0 at random_state 124
# 54.0 at random_state 125
# 57.99999999999999 at random_state 126
# 54.0 at random_state 127
# 64.0 at random_state 128
# 64.0 at random_state 129
# 57.99999999999999 at random_state 130
# 52.0 at random_state 131
# 56.00000000000001 at random_state 132
# 44.0 at random_state 133
# 64.0 at random_state 134
# 54.0 at random_state 135
# 40.0 at random_state 136
# 54.0 at random_state 137
# 48.0 at random_state 138
# 62.0 at random_state 139
# 54.0 at random_state 140
# 50.0 at random_state 141
# 50.0 at random_state 142
# 57.99999999999999 at random_state 143
# 56.00000000000001 at random_state 144
# 60.0 at random_state 145
# 52.0 at random_state 146
# 60.0 at random_state 147
# 50.0 at random_state 148
# 54.0 at random_state 149
# 68.0 at random_state 150
# 46.0 at random_state 151
# 50.0 at random_state 152
# 64.0 at random_state 153
# 48.0 at random_state 154
# 50.0 at random_state 155
# 52.0 at random_state 156
# 48.0 at random_state 157
# 50.0 at random_state 158
# 48.0 at random_state 159
# 57.99999999999999 at random_state 160
# 57.99999999999999 at random_state 161
# 54.0 at random_state 162
# 52.0 at random_state 163
# 62.0 at random_state 164
# 64.0 at random_state 165
# 64.0 at random_state 166
# 50.0 at random_state 167
# 52.0 at random_state 168
# 54.0 at random_state 169
# 57.99999999999999 at random_state 170
# 52.0 at random_state 171
# 62.0 at random_state 172
# 48.0 at random_state 173
# 60.0 at random_state 174
# 68.0 at random_state 175
# 50.0 at random_state 176
# 64.0 at random_state 177
# 57.99999999999999 at random_state 178
# 52.0 at random_state 179
# 57.99999999999999 at random_state 180
# 57.99999999999999 at random_state 181
# 66.0 at random_state 182
# 60.0 at random_state 183
# 44.0 at random_state 184
# 50.0 at random_state 185
# 48.0 at random_state 186
# 57.99999999999999 at random_state 187
# 60.0 at random_state 188
# 52.0 at random_state 189
# 54.0 at random_state 190
# 68.0 at random_state 191
# 54.0 at random_state 192
# 57.99999999999999 at random_state 193
# 56.00000000000001 at random_state 194
# 54.0 at random_state 195
# 38.0 at random_state 196
# 56.00000000000001 at random_state 197
# 62.0 at random_state 198
# 52.0 at random_state 199

# %% [markdown]
# Here accuracy of random state icreasing and decresing

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.30, random_state=i)
    mod = DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=1
print("Best accuracy is",maxAccu," on Random_state",maxRS)
# Out:
# Best accuracy is 0.8222222222222222  on Random_state 1

# %% [markdown]
# Here best accuracy is 0.8 and random state is 1

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.30, random_state =6)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred = DTC.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.43      0.86      0.57         7
#            2       0.00      0.00      0.00         2
#            3       0.50      0.67      0.57         6
#            4       0.00      0.00      0.00         8
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         3
#            8       0.89      0.80      0.84        10
#            9       0.50      0.17      0.25         6
#
#     accuracy                           0.42        45
#    macro avg       0.23      0.25      0.22        45
# weighted avg       0.40      0.42      0.39        45

# %% [markdown]
# Here the accuracy value of DecisionTressClassifier is 0.49

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
pred = RFC.predict(x_test)
acc=classification_report(y_test, pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.35      0.86      0.50         7
#            2       0.00      0.00      0.00         2
#            3       0.80      0.67      0.73         6
#            4       1.00      0.25      0.40         8
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         3
#            8       0.77      1.00      0.87        10
#            9       0.62      0.83      0.71         6
#
#     accuracy                           0.60        45
#    macro avg       0.44      0.45      0.40        45
# weighted avg       0.59      0.60      0.53        45

# %% [markdown]
# Here the accuracy value of RandomClassifier is 0.60

# %%
SV = SVC()
SV.fit(x_train,y_train)
pred = SV.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.35      0.86      0.50         7
#            2       0.00      0.00      0.00         2
#            3       0.40      0.33      0.36         6
#            4       0.00      0.00      0.00         8
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         3
#            8       0.47      0.70      0.56        10
#            9       0.38      0.50      0.43         6
#
#     accuracy                           0.40        45
#    macro avg       0.20      0.30      0.23        45
# weighted avg       0.26      0.40      0.31        45

# %% [markdown]
# Here the accuarcy value of StandardVectorClassifier is 0.40

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# 0.5289655172413793

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.5554022988505747

# %%
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.4149425287356322

# %% [markdown]
# Here all cross values of DTC,RFC and SVC

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'max_depth':np.arange(2,10),
             'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %% [markdown]
# Here we can take sklearn models criterion gini and entropy and estimator of DTC cv=5

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 6}

# %% [markdown]
# The best criterion is gini and max_depth is 2

# %%
Final_mod = DecisionTreeClassifier(criterion= 'gini',max_depth=6)
Final_mod.fit(x_train,y_train)
pred = Final_mod.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 51.11111111111111

# %% [markdown]
# The final mode pf accuracy is 51.111111

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(Final_mod,"FinalModle.pkl")
# Out:
# ['FinalModle.pkl']

# %% [markdown]
# The finalmodel of the joblib is FinalModel.pkl
